# %% [markdown]
# Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %% [markdown]
# Download titanic data from build-in data frames

# %%
tit = sns.load_dataset('titanic')

# %%
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
sns.jointplot(x='fare', y='age', data = tit, kind="kde", space=0, color="g")

# %%
sns.distplot(tit['fare'], kde=False)

# %%
sns.boxplot(x='pclass', y='age', data=tit, palette='rainbow')

# %%
import numpy as np
sns.barplot(x='class', y='fare', data=tit, hue = 'alone',estimator=np.median)

# %%
sns.barplot(x='alone', y='age', data=tit, estimator=np.median)

# %%
sns.stripplot(x='alive',y='age', data=tit, hue = 'class', dodge=True)

# %%
sns.heatmap(tit.corr())

# %%
a = sns.FacetGrid(tit, row="sex", row_order=["male", "female"])
a = a.map(plt.hist, "fare", color="b")

# %%
g = sns.FacetGrid(tit, col="class", row="sex", hue='alive')
g = g.map(plt.scatter, "age", "fare").add_legend();

# %% [markdown]
# Build three customized various graphs using knowledge from:
# http://seaborn.pydata.org/tutorial/aesthetics.html

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sinplot()

# %%
sns.boxplot(data=tit, palette="deep")
sns.despine(left=True)

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

with sns.axes_style("darkgrid"):
    ax = f.add_subplot(gs[0, 0])
    sinplot()

with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 1])
    sinplot()

with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 0])
    sinplot()

with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[1, 1])
    sinplot()

f.tight_layout()
